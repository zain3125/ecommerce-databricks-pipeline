# %%
# Dimtables
from src.gold.dimensions.dim_date import create_dim_date
from src.gold.dimensions.dim_payment_type import load_dim_payment_type
from src.gold.dimensions.dim_products import load_dim_products
from src.gold.dimensions.dim_sellers import load_dim_sellers
from src.gold.dimensions.dim_customers import load_dim_customers

# Facttables
from src.gold.facts.fact_order_items import load_fact_order_items
from src.gold.facts.fact_payments import load_fact_payments
from src.gold.facts.fact_reviews import load_fact_reviews
from src.gold.facts.fact_orders import load_fact_orders

loads = [
    create_dim_date,
    load_dim_payment_type,
    load_dim_sellers,
    load_dim_customers,
    load_dim_products,

    load_fact_payments,
    load_fact_reviews,
    load_fact_order_items,
    load_fact_orders,
]

for load in loads:
    load(spark)
