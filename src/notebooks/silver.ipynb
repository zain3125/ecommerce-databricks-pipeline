# %%
from src.silver.orders import transform_orders
from src.silver.product_category_name_translation import transform_product_category_name_translation
from src.silver.geolocation import transform_geolocation
from src.silver.sellers import transform_sellers
from src.silver.products import transform_products
from src.silver.customers import transform_customers
from src.silver.order_items import transform_order_items
from src.silver.payments import transform_payments
from src.silver.reviews import transform_reviews

transformations = [
    transform_orders,
    transform_product_category_name_translation,
    transform_geolocation,
    transform_sellers,
    transform_products,
    transform_customers,
    transform_order_items,
    transform_payments,
    transform_reviews,
]

for transform in transformations:
    transform(spark)
